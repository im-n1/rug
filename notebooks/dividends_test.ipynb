# %%
from rug.stocktwits import UnofficialAPI

# %%
api = UnofficialAPI("QCOM")
api.get_dividends()
# Out:
# [{'yield': 0.02849,
#   'sector_average_yield': 0.01216,
#   'payment_date': '2020-03-26T00:00:00',
#   'ex_date': '2020-03-04T00:00:00',
#   'receive_date': '2020-03-05T00:00:00',
#   'growth_since': '2004-08-25T00:00:00'},
#  {'yield': 0.02849,
#   'sector_average_yield': 0.01216,
#   'payment_date': '2019-12-19T00:00:00',
#   'ex_date': '2019-12-04T00:00:00',
#   'receive_date': '2019-12-05T00:00:00',
#   'growth_since': '2004-08-25T00:00:00'},
#  {'yield': 0.02849,
#   'sector_average_yield': 0.01216,
#   'payment_date': '2019-09-26T00:00:00',
#   'ex_date': '2019-09-11T00:00:00',
#   'receive_date': '2019-09-12T00:00:00',
#   'growth_since': '2004-08-25T00:00:00'},
#  {'yield': 0.02849,
#   'sector_average_yield': 0.01216,
#   'payment_date': '2019-06-27T00:00:00',
#   'ex_date': '2019-06-05T00:00:00',
#   'receive_date': '2019-06-06T00:00:00',
#   'growth_since': '2004-08-25T00:00:00'},
#  {'yield': 0.02849,
#   'sector_average_yield': 0.01216,
# ...
